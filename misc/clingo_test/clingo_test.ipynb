# %%
import json

# %%
# Load the JSON file
file_path = "test.cse.json"
with open(file_path, "r") as file:
    course_data = json.load(file)

# %%
# # Function to convert the JSON data to Prolog facts
# def generate_prolog_courses(course_data):
#     prolog_lines = []
#     for course_id, details in course_data.items():
#         course_num = course_id
#         try:
#             credits = int(details["Credits"])  # Assuming credits are always whole numbers
#         except ValueError:
#             # credits = details["Credits"]
#             continue
#         prerequisites = details["Prerequisites"]
#         career = details["Career"]

#         # Flatten prerequisites list if nested
#         if prerequisites != "NONE":
#             flat_prereqs = [item.lower() for sublist in prerequisites for item in sublist]
#             # flat_prereqs = prerequisites
#         else:
#             flat_prereqs = []
        
#         # Using a list comprehension to remove spaces from strings in nested lists
#         flat_prereqs = [
#             item.replace(" ", "") if isinstance(item, str) 
#             else [subitem.replace(" ", "") for subitem in item] 
#             for item in flat_prereqs]

#         # Create Prolog fact string
#         # prolog_line = f"course({course_num.lower()}, {credits}, {tuple(flat_prereqs)}, \"{career}\")."
#         prolog_line = f"course({course_num.lower()}, {credits}, {tuple(flat_prereqs)})."
#         prolog_lines.append(prolog_line)

#     return prolog_lines


# # Generate the Prolog facts
# prolog_courses = generate_prolog_courses(course_data)
# prolog_courses

# %%
# def process_courses(course_data):
#     # Define a function to format the courses as required by the Clingo code
#     clingo_courses = []

#     for code, details in course_data.items():
#         course_number = code
#         try:
#             credits = int(
#                 details["Credits"]
#             )  # Cast to int, assuming credits are provided as a float or int
#         except ValueError:
#             credits = details["Credits"]
#         prerequisites = details.get("Prerequisites", [])
#         career = details["Career"]

#         # Handle prerequisites formatting
#         if isinstance(prerequisites, list):
#             if prerequisites and isinstance(prerequisites[0], list):
#                 prerequisites = [
#                     pr[0].split()[-1] for pr in prerequisites
#                 ]  # Simplify prerequisites references
#             else:
#                 prerequisites = [
#                     p.split()[-1] for p in prerequisites
#                 ]  # Assuming course code is last in string
#         elif prerequisites == "NONE":
#             prerequisites = []

#         # Format for Clingo
#         clingo_course = (
#             f'course({course_number.lower()}, {credits}, {prerequisites}, "{career}")'
#         )
#         clingo_courses.append(clingo_course)

#     return clingo_courses


# # Call the function to process and get the formatted courses
# formatted_courses = process_courses(course_data)
# formatted_courses

# %%
def process_course_data(file_path):
    # Load JSON data from the file
    with open(file_path, 'r') as file:
        data = json.load(file)

    courses_list = []
    prerequisites_list = []

    # Process each course in the JSON data
    for course_code, details in data.items():
        # Extract course information
        course_name = course_code  # Simplified as the key
        try:
            credits = int(details['Credits']) if isinstance(details['Credits'], (float, int)) else 3  # Assuming default 3 if not clear
        except ValueError:
            continue
        prerequisites = details.get('Prerequisites', [])

        # Print course information
        # print(f"course({course_name.lower()}, {credits}).")

        courses_list.append(f"course({course_name.lower()}, {credits}).")

        # Process and print prerequisites
        if prerequisites != "NONE" and isinstance(prerequisites, list):
            for prereq_list in prerequisites:
                for prereq in prereq_list:
                    # Format and clean prerequisite course code
                    prereq_code = prereq.replace(" ", "").upper()
                    # print(f"prerequisite({course_name.lower()}, {prereq_code.lower()}).")
                    if 'cs' in prereq_code.lower():
                        if prereq_code.lower() < course_name.lower():
                            prerequisites_list.append(f"prerequisite({course_name.lower()}, {prereq_code.lower()}).")
                        # prerequisites_list.append(f"prerequisite({course_name.lower()}, {prereq_code.lower()}).")
    
    output = courses_list + prerequisites_list

    return output

# Example of calling the function
# file_path = '/path/to/json/file.json'  # Specify the correct path to the JSON file
output = process_course_data(file_path)
output
# Out:
# ['course(cse101, 3).',
#  'course(cse102, 3).',
#  'course(cse110, 3).',
#  'course(cse113, 4).',
#  'course(cse114, 4).',
#  'course(cse130, 3).',
#  'course(cse150, 4).',
#  'course(cse160, 3).',
#  'course(cse161, 1).',
#  'course(cse190, 3).',
#  'course(cse191, 3).',
#  'course(cse192, 3).',
#  'course(cse213, 4).',
#  'course(cse214, 4).',
#  'course(cse215, 4).',
#  'course(cse216, 4).',
#  'course(cse220, 4).',
#  'course(cse230, 3).',
#  'course(cse260, 3).',
#  'course(cse261, 1).',
#  'course(cse300, 3).',
#  'course(cse301, 3).',
#  'course(cse303, 3).',
#  'course(cse304, 3).',
#  'course(cse305, 3).',
#  'course(cse306, 3).',
#  'course(cse307, 3).',
#  'course(cse310, 3).',
#  'course(cse311, 3).',
#  'course(cse312, 3).',
#  'course(cse316, 3).',
#  'course(cse320, 3).',
#  'course(cse323, 3).',
#  'course(cse325, 3).',
#  'course(cse327, 3).',
#  'course(cse328, 3).',
#  'course(cse331, 3).',
#  'course(cse332, 3).',
#  'course(cse333, 3).',
#  'course(cse334, 3).',
# ...

# %%
def write_list_to_file(data_list, filename):
    with open(filename, "w") as file:
        for item in data_list:
            file.write(item + "\n")

# %%
write_list_to_file(output, "courses.pl")

# %%
'cse802' > 'cse506'
# Out:
# True
